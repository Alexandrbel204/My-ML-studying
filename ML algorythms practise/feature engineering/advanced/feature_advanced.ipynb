# %% [markdown]
# # 1. Boruta
# ## Boruta — это обёртка над случайным лесом (или другим деревом), которая пытается определить все релевантные признаки, а не только минимальный набор.
#
# ### 💡 Идея:
# * Берёт все признаки и создаёт их случайные "тени" (shadow features), перемешивая значения.
# * Обучает RandomForest, оценивает важность настоящих и теневых признаков.
# * Если признак важнее, чем любая из его теней — он "сохраняется".
# * Иначе — отклоняется или продолжает сравниваться.
#
# ### ✅ Преимущества:
# * Автоматически определяет релевантные фичи.
# * Не требует ручной настройки.
# * Работает при сильной нелинейности.

# %% [markdown]
# # 2. SHAP (SHapley Additive exPlanations)
# ## SHAP — это метод из интерпретируемого ML. Он показывает вклад каждого признака в прогноз модели на уровне как отдельного примера, так и всей выборки.
#
# ### 💡 Идея:
# * Основан на теории игр (Shapley values).
# * Смотрит, насколько изменится предсказание модели, если добавить признак.
# * И оценивает важность фичей с учётом всех возможных подмножеств признаков.
#
# ### ✅ Преимущества:
# * Работает с любыми моделями (особенно с tree-based).
# * Даёт локальные объяснения: почему модель сделала такой прогноз.
# * Учитывает взаимодействия признаков.

# %%
from IPython.display import Image
Image('compare.png')
